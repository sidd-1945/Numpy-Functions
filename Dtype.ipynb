# %%
import numpy as np
a = np.arange(10)
a.dtype

# %%
import numpy as np
a = np.arange(10,dtype = 'float64')
a.dtype

# %%
import numpy as np
a = np.array([True,False,True,False])
a.dtype

# %%
import numpy as np
a = np.array([1+2j,2+4j]) #Complex Datatype
a.dtype

# %%
import numpy as np
a = np.array(['Cristiano','Messi','Neymar']) #output: <U9, why 9 because length of cristiano is 9 which is greatest
a.dtype
