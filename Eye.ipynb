# %%
import numpy as np
a = np.eye(3)
a
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
import numpy as np
a = np.eye(3,2)
a
# Out:
# array([[1., 0.],
#        [0., 1.],
#        [0., 0.]])
